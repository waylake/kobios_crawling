# %%
import requests
from bs4 import BeautifulSoup

# URL 정의
url = "https://kobis.or.kr/kobis/business/stat/boxs/findPeriodScreenTicketList.do"

# Fake Header 정의
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
    "Referer": "https://kobis.or.kr",
    "Content-Type": "application/x-www-form-urlencoded",
}

# Payload 정의
payload = {
    "CSRFToken": "G1P5qi2QQzdb48cAT4etN5FEw5HKBf3uH2jfE9rWzEI",
    "loadEnd": "0",
    "curTime": "2024-06-07",
    "totScrnCntOrder": "",
    "totScrnCntRatioOrder": "",
    "totDspCntOrder": "",
    "totIssuAmtOrder": "",
    "addTotIssuAmtOrder": "",
    "totIssuCntOrder": "",
    "addTotIssuCntOrder": "",
    "dmlMode": "search",
    "startDate": "2024-06-01",
    "endDate": "2024-06-07",
    "repNationCd": "",
    "wideareaCd": ""
}

# POST 요청 보내기
response = requests.post(url, headers=headers, data=payload)

# BeautifulSoup으로 HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 영화별 스크린점유율 파싱
table_datas = soup.find('tbody', {'id': 'mainTbody'}).find_all('tr')
movie_screen_ratios = []

for row in table_datas:
    movie_name = row.find('td', {'id': 'td_movie'}).get_text(strip=True)
    screen_ratio = row.find('td', {'id': 'td_totScrnCntRatio'}).get_text(strip=True)
    movie_screen_ratios.append((movie_name, screen_ratio))

# 결과 출력
for movie, ratio in movie_screen_ratios:
    print(f"영화: {movie}, 스크린점유율: {ratio}")
# Out:
# 영화: 퓨리오사: 매드맥스 사가, 스크린점유율: 12.0%
# 영화: 원더랜드, 스크린점유율: 10.3%
# 영화: 설계자, 스크린점유율: 9.8%
# 영화: 그녀가 죽었다, 스크린점유율: 8.0%
# 영화: 범죄도시4, 스크린점유율: 7.9%
# 영화: 나쁜 녀석들: 라이드 오어 다이, 스크린점유율: 6.8%
# 영화: 극장판 하이큐!! 쓰레기장의 결전, 스크린점유율: 4.6%
# 영화: 가필드 더 무비, 스크린점유율: 4.0%
# 영화: 존 오브 인터레스트, 스크린점유율: 3.4%
# 영화: 드림 시나리오, 스크린점유율: 2.9%
# 영화: 창가의 토토, 스크린점유율: 2.8%
# 영화: 혹성탈출: 새로운 시대, 스크린점유율: 2.5%
# 영화: 명탐정 코난 VS 괴도 키드, 스크린점유율: 2.4%
# 영화: 청춘 18X2 너에게로 이어지는 길, 스크린점유율: 2.4%
# 영화: 바커스: 슈퍼스타가 될 거야, 스크린점유율: 1.5%
# 영화: 빼꼼: 미션 투 마스, 스크린점유율: 1.4%
# 영화: 태극기 휘날리며, 스크린점유율: 1.4%
# 영화: 금지된 장난, 스크린점유율: 1.0%
# 영화: 코코, 스크린점유율: 1.0%
# 영화: 오늘부터 댄싱퀸, 스크린점유율: 0.9%
# 영화: 분노의 강, 스크린점유율: 0.7%
# 영화: 결속밴드 라이브 -항성-, 스크린점유율: 0.6%
# 영화: 이프: 상상의 친구, 스크린점유율: 0.6%
# 영화: 소울메이트, 스크린점유율: 0.6%
# 영화: 김준수 콘서트 무비 챕터 원 : 레크리에이션, 스크린점유율: 0.6%
# 영화: 악마와의 토크쇼, 스크린점유율: 0.6%
# 영화: 남은 인생 10년, 스크린점유율: 0.5%
# 영화: 별처럼 빛나는 너에게 더무비-일섬일섬량성성, 스크린점유율: 0.5%
# 영화: 아침이 오면 공허해진다, 스크린점유율: 0.4%
# 영화: 찬란한 내일로, 스크린점유율: 0.4%
# 영화: 쇼생크 탈출, 스크린점유율: 0.4%
# 영화: 정욕, 스크린점유율: 0.3%
# ...
